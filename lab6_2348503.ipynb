# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleena24/ML_Lab/blob/main/lab6_2348503.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df = pd.read_csv('/content/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Check for missing values
is_null = df.isnull()

# Count the number of missing values in each column
missing_values_count = is_null.sum()

# Print the number of missing values in each column
print(missing_values_count)
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# Create a one-hot encoder
one_hot_encoder = OneHotEncoder(handle_unknown='ignore')

# Fit the one-hot encoder to the data
one_hot_encoder.fit([sex, smoker, region])

# Encode the data
encoded_sex, encoded_smoker, encoded_region = one-hot-encoder.transform([sex, smoker, region])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6d9af875a28c> in <cell line: 7>()
#       5
#       6 # Fit the one-hot encoder to the data
# ----> 7 one_hot_encoder.fit([sex, smoker, region])
#       8
#       9 # Encode the data
#
# NameError: name 'sex' is not defined
